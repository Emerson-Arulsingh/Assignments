# %%
#21. Terminal Execution Task
#Create a Python file named calculator.py containing separate functions for:
#add()
#subtract()
#multiply()
#divide()
#Then execute the program through the terminal using:
#python calculator.py
#The program should accept two numbers from the user and display the results of all four operations.

import sys
def add (a, b):
    sum = a + b
    return sum

def subtract (a, b):
    diff = a - b
    return diff

def multiply (a, b):
    mul = a * b
    return mul

def divide (a, b):
    diff = a - b
    return diff    

def main():
    print("Hello from the terminal!")
    a = 8 
    b = 5
    print(add(a,b))
    print(subtract(a,b))
    print(multiply(a,b))
    print(divide(a,b))

if __name__ == "__main__":
    main()
# Out:
# Hello from the terminal!
# 13
# 3
# 40
# 3
